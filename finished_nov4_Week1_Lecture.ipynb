# %% [markdown]
# <a href="https://colab.research.google.com/github/onni-Q/python_assignments/blob/main/finished_nov4_Week1_Lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Introduction Lecture
#
# ## Interacting with Environment

# %% [markdown]
# Welcome to your first session on how to use Python interactively in Jupyter Notebooks.
#
# By the end of this session, you will be able to:
# - use Jupyter Notebooks for basic calculations
# - understand fundamental Python data types
# - work with variables
# - use built-in functions
# - create and manipulate lists,
# - and understand basic control flow (if/else) and loops (for).
#
# Let's just try to get used to interacting with the environment. Run the cell below by using 'run' in the menu or click on the little grey arrow on the left. You can also use keyboard shortcuts: 'ctrl + enter to run current cell' (https://colab.research.google.com/drive/13IO3-gfyS9mSPuzAo6-wsYBUOVpxb_va?usp=sharing#scrollTo=bkyJsT1wCDbn).

# %%
# Keep cell
4
# Out:
# 4

# %% [markdown]
# It is printing! The notebook displayed the number 4. This is because Jupyter notebooks will automatically display the result of the last unassigned expression in a code cell.
#
# Let's try to add two numbers. Please, type ```2 + 1``` into cell below. Then, press run the cell.

# %%
2 + 1
# Out:
# 3

# %% [markdown]
# Now, let's try ```10 - 3```.

# %%
10 - 3
# Out:
# 7

# %% [markdown]
# In the next cell try out further operations. Try multiplication with `3 * 7` and/or division with `10 / 2`.

# %%
3 * 7
# Out:
# 21

# %% [markdown]
# And finally, brackets can be used to indicate that operators in the sub-expression take precedence - just like at school math. Try ```(1 * 2) - 100```.

# %%
(1 * 2) - 100
# Out:
# -98

# %% [markdown]
# These were all numbers. All this is very similar to what you know from calculators. But computers can process many other symbols as well. Other important symbols include 'strings', which you know as words. These can be any number of characters like 'a', 'b', 'c', etc. but also '-', '1' or '&' can be  characters.
#
# Let's try this ...
#
# Please, type ```'Amsterdam'``` into the Cell's prompt. The quotation marks indicate that this is a string. You could also use double quotation marks: ```"Amsterdam"```.
#
# Normally, it does not matter much which version of quote you use, but it is useful if you have quotes within the string. Then, use the single quote for the whole string and the double quote for the quote: "This is useful if your string itself contains one type of quote, e.g., 'He said "Hello!"'

# %%
'Amsterdam'
# Out:
# 'Amsterdam'

# %% [markdown]
# What do you see when you enter ```type('Amsterdam')```?

# %%
type('Amsterdam')
# Out:
# str

# %% [markdown]
# str stands for strings.
#
#
# ## Data Types
#
# There are many more types, which we will cover throughout the course. Check out: https://realpython.com/python-data-types/
#
#
# We have already used so-called integers, which are basic numbers. Try ```type(333)```

# %%
type(333)
# Out:
# int

# %% [markdown]
# Numbers in Python are generally either integers (those without a floating point) or floats (those with a floating point). Check out https://docs.python.org/3/library/stdtypes.html for an overview of all the different numerical types in Python. It looks scary but in practice we only use two more types. The first are floating point numbers, which have a decimal point. Enter ```type(3.14)```.

# %%
type(3.14)
# Out:
# float

# %% [markdown]
# Booleans are second important type we use regularly. They evaluate whether an assumption is True or False. Please, type ```10 < 8```. What do you get back?

# %%
10 < 8
# Out:
# False

# %% [markdown]
# The statement is false. This False value is a so-called Boolean. You can check its type with `type(10 < 8)`.

# %%
type(10 < 8)
# Out:
# bool

# %% [markdown]
# Other comparison operators include > (greater than), == (equal to), != (not equal to), >= (greater than or equal to), and <= (less than or equal to). Try a few by overwriting the last cell.
#
# You can also add numbers of different types like in a calculator. Try ```333 + 3.14```.

# %%
333 + 3.14
# Out:
# 336.14

# %% [markdown]
# What is the type of the result? Try `type(333 + 3.14)`. This demonstrates type successful type conversion: (int + float -> float).

# %%
type(333 + 3.14)
# Out:
# float

# %% [markdown]
# A common error is the attempt to combine two data types that do not really go together without providing  more details. Try ```'three' + 3```.

# %% [markdown]
# You cannot add a string to an int. Seems logical, no?
#
# Variables are another important concept that discriminates programming languages from calculators. They are basically names for places in the computer's memory where we can store things. We create variables with the Python assignment operator =.
#
# Let's try that and assign the value 4 to the variable `my_friends`. Please, type in ```my_friends = 4``` for the number of friends I have.

# %%
my_friends = 4

# %% [markdown]
# Well done. Using descriptive names like `my_friends` instead of just `x` makes your code much easier to understand later. Always follow this principle. It is very good practice to use names that you can understand in 10 years when you look at your code again.
#
# Now print out my_friends. Just type ```my_friends```.

# %%
my_friends
# Out:
# 4

# %% [markdown]
# Now let's try to assign another variable for my number of colleagues.
#
# Type ```my_colleagues = 3```.

# %%
my_colleagues = 3

# %% [markdown]
# You have now created two variables `my_friends` and `my_colleagues`.
#
# Just like numbers we can add two numerical variables. Please try it with ```my_friends + my_colleagues```.

# %%
my_friends + my_colleagues
# Out:
# 7

# %% [markdown]
# We can also assign the result to a new `variable my_friends_and_colleagues`. Please type ```my_friends_and_colleagues = my_friends + my_colleagues```.

# %%
my_friends_and_colleagues = my_friends + my_colleagues

# %% [markdown]
# I am using the _ to separate words in variable names. This is common good practice.
#
# To check that the new variable exists, please enter ```my_friends_and_colleagues```.

# %%
my_friends_and_colleagues
# Out:
# 7

# %% [markdown]
# But we can only combine variables of the same type. Please assign the string 'six' to my_colleagues with ```my_colleagues = 'six'```.

# %%
my_colleagues = 'six'

# %% [markdown]
# Now let's try and 'add' `my_friends` and `my_colleagues`. Type ```my_friends + my_colleagues``` and you will get an error.

# %%
my_friends_and_colleagues
# Out:
# 7

# %% [markdown]
# Variables are very important in any programming language.
#
# Another key idea is the function. It is  a predefined set of commands. On your calculator you can, for instance, use the inv-function to get the inverse of a number. Python also has a lot of pre-defined functions like inv. But in any programming language you can also define your own functions. We will come back to this later. For now, we stay with pre-defined functions.
#
# In Python, functions are called with arguments in brackets. They are often found in extra libraries that are basically collections of functions. More on libraries also later ...
#
# You have already used the type function to determine the type of numbers and strings. There are many, many more.
#
# Please run ```round(3.78)``` to run the built-in math function round in Python. You should get 4. ```round``` is the function name and 3.78 is the only 'argument' as the input into functions is called.

# %%
round(3.78)
# Out:
# 4

# %% [markdown]
# We can count the number of characters in a string with the function ```len```. Run ```len('Amsterdam')```.

# %%
len('Amsterdam')
# Out:
# 9

# %% [markdown]
# Functions work with all data types as arguments. Let's try one more with ```abs(-10)```. What does this do?

# %%
abs(-10)
# Out:
# 10

# %% [markdown]
# `abs` returns the absolute value of a number.
#
# Check out https://docs.python.org/3/library/functions.html for a complete overview of all built-in functions. Play with a few more ... Some might be hard to understand at this time.
#
# One important function that we have not talked about is ```print```. It simply prints out a statement. Try ```print('Amsterdam')```.

# %%
print('Amsterdam')
# Out:
# Amsterdam

# %% [markdown]
# Jupyter Notebooks automatically print the result of the last expression in a code cell if it's not assigned to a variable. This contrasts with using the `print()` function, which is more explicit and can print multiple things.
#
#
# You can print integers, too. Enter ```print(5)```.

# %%
print(5)
# Out:
# 5

# %% [markdown]
# As you can see at https://realpython.com/python-print/, `print` is very powerful and has a lot of options to format the output. For instance, if you type in ```print('Hello', 'Amsterdam', sep='_')```. You print out Hello_Amsterdam. The strings are concatenated using the sep argument, which is '_'.

# %%
print('Hello', 'Amsterdam', sep = '_')
# Out:
# Hello_Amsterdam

# %% [markdown]
# With '\n', you indicate a line break. What happens if you type in ```print('Hello', 'Amsterdam', sep='\n')```. Try it.

# %%
print('Hello', 'Amsterdam', sep = '\n')
# Out:
# Hello
# Amsterdam

# %% [markdown]
# There are many advanced formatting options for print, we will cover in the course.
#
# Next to numbers, strings are very important in Python and other languages. They come with many functions as well. Check out: https://docs.python.org/3/library/string.html. We have already seen ```len``` and will cover many more string functions in this course. One important one is concatenation outside ```print```. In Python, the ```+``` operator is used again. Try ```'Hello' + ' Amsterdam'```.

# %%
'Hello' + 'Amsterdam'
# Out:
# 'HelloAmsterdam'

# %% [markdown]
# You can also concatenate several strings. Type in ```'Hello' + ' ' + 'Amsterdam'```.

# %%
'Hello' + ' ' + 'Amsterdam'
# Out:
# 'Hello Amsterdam'

# %% [markdown]
# There is a more recent development in Python called f-strings as a modern way to format strings, especially if these are mixing text and variables. Run the next cell and try to understand.

# %%
#Keep cell

name = 'Me'
age = 20

print(f"Hello, {name}! You are {age} years old.")
# Out:
# Hello, Me! You are 20 years old.

# %% [markdown]
# As you can see in the `print` statement, the `f` before the string makes it easy to integrate variables with the `{}` brackets.
#
# f-strings have gained a lot of traction in recent years with the work on chatbots, as we will see in later sessions. Here. we focus on other more introductory concepts and move on to combining data in lists and arrays.
#
#
#
# ## List and Arrays
#
#
# With so-called lists, you can collect several elements in the same variable. This is immensely useful for collecting data. You will see a lot of use of data collections in this course.
#
# Let's try to make lists, which store an ordered set of values called elements. A list can contain any number of elements using brackets. They are ordered, mutable (can be changed) and can hold items of different types.
#
# Type in `numeric_list = [3, 9, 27]` to create a numeric list of three numbers.

# %%
numeric_list = [3, 9, 27]

# %% [markdown]
# To check that the new list exists, please type ```numeric_list```.

# %%
numeric_list
# Out:
# [3, 9, 27]

# %% [markdown]
# We can also create a string/characters list, with ```string_list = ['abc', 'def', 'ghi']```.

# %%
string_list = ['abc', 'def', 'ghi']

# %% [markdown]
# To check that the new list exists, please type ```string_list```.

# %%
string_list
# Out:
# ['abc', 'def', 'ghi']

# %% [markdown]
# Lists are useful to, for instance, keep a record of the friends you meet during the week. You do not see friends on Saturday and Sunday, as you stay home with family, but you record all the other 5 days. You enter ```friends_list = [2, 3, 2, 4, 5]```.

# %%
friends_list = [2, 3, 2, 4, 5]

# %% [markdown]
# You feel very communicative this week. So, you also meet up with colleagues. Please record your meetings with ```colleagues_list =[3, 1, 1, 10, 2]```.

# %%
colleagues_list = [3, 1, 1, 10, 2]

# %% [markdown]
# Because you prefer it organised, you would now like to name each of the entries. Such 'named lists' are possible in Python with dictionaries. Please create an empty dictionary by typing ```names_friends = {}```.

# %%
names_friends = {}

# %% [markdown]
# To create a dictionary (which is like a named list), simply use the {} and then for each element the key to access the element comes first, then a ':', and finish it with the value.
#
# So, in order to create a dictionary containing all your friends, type in ```names_friends = {'Monday': 2, 'Tuesday': 3, 'Wednesday': 2, 'Thursday': 4, 'Friday': 5}```.
#
# Dictionaries are further explained at https://www.w3schools.com/python/python_dictionaries.asp.

# %%
names_friends = {'Monday': 2, 'Tuesday': 3, 'Wednesday': 2, 'Thursday': 4, 'Friday': 5}

# %% [markdown]
# Let's take a look at the type with `type(names_friends)`. Type it in.

# %%
type(names_friends)
# Out:
# dict

# %% [markdown]
# Python dictionaries use curly braces `{}` with key-value pairs: `key: value`, separated by commas. Keys must be unique.
#
# Now you can access a single element with ```names_friends['Monday']```.

# %%
names_friends['Monday']
# Out:
# 2

# %% [markdown]
# This was just an introduction to dictionaries. We will come back to them many times throughout this course.
#
# Next, you are interested in how many people you meet per week.
#
# You can simply add up all the elements in the list. Remember that we can use built-in functions?
#
# To add up elements in a list we can use the function sum, which comes directly with Python. Try it with ```sum(friends_list)```.

# %%
sum(friends_list)
# Out:
# 16

# %% [markdown]
# And of course we can also do ```sum(colleagues_list)```.

# %%
sum(colleagues_list)
# Out:
# 17

# %% [markdown]
# In order to get our total meetings for the week, we can simply add both lists with the Python `sum` function. Type in ```total_week = sum(friends_list) + sum(colleagues_list)```.

# %%
total_week = sum(friends_list) + sum(colleagues_list)

# %% [markdown]
# Print out `total_week`.

# %%
print(total_week)
# Out:
# 33

# %% [markdown]
# We have almost covered everything there is to know about lists. One more important concept is that lists are indexed. Using square brackets, we can select the first, second and third element directly with 0, 1, 2, etc. respectively. So, the index count in Python starts with 0 for the first element. The last element is then the length of the list n – 1.
#
# To select Monday's friends (first day of the week) simply use square brackets [] and type ```friends_monday = friends_list[0]```.

# %%
friends_monday = friends_list[0]

# %% [markdown]
# Print out `friends_monday`.

# %%
print(friends_monday)
# Out:
# 2

# %% [markdown]
# You can also select more than one element with the colon `:` operator.
#
# In order to select your meetings with colleagues from Tuesday to Thursday, please run ```colleagues_selection_list = colleagues_list[1:4]```.  The first value, left of the colon, is the first index to select (in this case Tuesday). The last value is the first index NOT to select (here an imaginary Friday). Watch out, as it can be confusing.
#
# Print out colleagues_selection_list in the same cell. You do this by entering each command in one line:
# ```
# colleagues_selection_list = colleagues_list[1:4]
# colleagues_selection_list
# ```

# %%
colleagues_selection_list = colleagues_list[1:4]
colleagues_selection_list
# Out:
# [1, 1, 10]

# %% [markdown]
# This is called list slicing in Python and requires some getting used to. It is, however, a key element of Python for working with datasets.
#
# If you have a list l, these are the options:
#
# - l[start:stop]  # items start through stop-1
# - l[start:]      # items start through the rest of the array
# - l[:stop]       # items from the beginning through stop-1
# - l[:]           # a copy of the whole array
#
#
# You can also use negative indices. `friends_list[-1]` gives you the last element, `friends_list[-2]` the second to last, and so on. Try getting the last element of `friends_list`.

# %%
friends_list[-1]
# Out:
# 5

# %% [markdown]
# To find out about our the total number of colleagues' meetings from Tuesday to Friday, we can use `sum` again. Try ```sum(colleagues_selection_list)```.

# %%
sum(colleagues_selection_list)
# Out:
# 12

# %% [markdown]
# Using the index we can also update elements in lists.
#
# Let's see the Wednesday meetings of colleagues_selection_list to 1000 with ```colleagues_selection_list[1] = 1000```.

# %%
colleagues_selection_list[1] = 1000

# %% [markdown]
# Print out `colleagues_selection_list` and its sum of the list in the same cell. You need to use `print()` for both statements, as otherwise you will only print out the last statement.

# %%
print(colleagues_selection_list)
# Out:
# [1, 1000, 10]

# %% [markdown]
# We can change lists by appending items at the end. This is done with the ```append``` function. Try to run ```colleagues_selection_list.append('10')```. You have updated the lists with a new item at the end. Print `colleagues_selection_list` in the same cell.

# %%
colleagues_selection_list.append('10')
colleagues_selection_list
# Out:
# [1, 1000, 10, '10']

# %% [markdown]
# Run the cell a couple of times. Each time a new '10' will be appended. Also, note that '10' is a string. Lists can contain different data types.
#
# With ```remove```, you will remove the items again. Try ```colleagues_selection_list.remove('10')```. Print out the list.

# %%
colleagues_selection_list.remove('10')

# %% [markdown]
# Please note, `remove()` will only remove the first occurrence of the item. If the item is not found, Python will raise a `ValueError`.
#
# It's time to practice some more at https://www.w3schools.com/python/python_lists.asp.
#
# Two more items common in data analysis are sets and tuples. Both are closely related to lists, and we only mention their common use cases.
#
# Sets is a construct you already know from school and means a list without duplicates. Type in `set(friends_list)` and compare the results with ```friends_list```.

# %%
set(friends_list)
friends_list
# Out:
# [2, 3, 2, 4, 5]

# %% [markdown]
# You have just eliminated duplicates from ```friends_list```.
#
# Tuples are used to store multiple items in a single variable. They are unchangeable. We cannot change, add or remove items after the tuple has been created.
#
# The example at https://www.w3schools.com/python/python_tuples.asp is ```my_tuple = ('apple', 'banana', 'cherry')```. Type it in and print it out.

# %%
my_tuple = ('apple', 'banana', 'cherry')
print(my_tuple)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# Try ```my_tuple[0] = 'kiwi'``` and you will get an error. Tuples are immutable.

# %% [markdown]
# Tuples might look a bit strange, but they will be useful later, when we create and modify more complex datasets. For now, just remember that *lists are using `[]`, dictionaries `{}` and tuples `()`*.
#
# The next new concept is the numpy array. You often use this construct in data analysis.
#
# Numpy has been a long-standing toolkit for data analysis. According to https://numpy.org/, it is 'the fundamental package for scientific computing with Python'. It features heavily in what is still a standard introduction in our field: https://wesmckinney.com/pages/book.html. It is a really good book to further work on the topics that are discussed in these introductions.
#
# First, we have to import the numpy package. This simply means that import all the functionalities and data that are associated with the package. You always do that in Python with import. In this case, type in ```import numpy```.

# %%
import numpy

# %% [markdown]
# A Python package is a container with various functions to perform specific tasks. For example, the math package includes the `sqrt()` function to perform the square root of a number. Run
# ```
# import math
# math.sqrt(9)
# ```

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %% [markdown]
# We will use a lot of packages and import other functions. This is all part of building complex programmes around the principles of abstraction and modularity: https://courses.csail.mit.edu/6.01/spring07/psets/lecture1.pdf. In the future, you can also contribute by providing your own packages.
#
# If you use a package very often and you are too lazy to type in the full name each time, you can also create a short version.
#
# To call `numpy` `np`, try ```import numpy as np```.

# %%
import numpy as np

# %% [markdown]
# Now you can create a numpy array with ```np.array([1,2,3,4])```. As you can see, you provide `np.array` with a Python list. Why do we then not use a simple list, you may ask? Arrays are much more powerful, as we will see.

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# Numpy arrays are designed for efficient numerical operations, especially on large datasets. They typically store elements of the same data type, unlike Python lists. And, they are very important for machine learning, as we will see from week 3 onwards.
#
# We will now recreate our social life examples using numpy arrays.
#
# Type in ```friends_array = np.array([5,4,2,1,3])``` to record the number of times you have met with friends.

# %%
friends_array = np.array([5,4,2,1,3])

# %% [markdown]
# Now, create ```colleagues_array = np.array([1,10,8,1,5])```.

# %%
colleagues_array = np.array([1,10,8,1,5])

# %% [markdown]
# Print out `colleagues_array` to see that it is numpy array.

# %%
print(colleagues_array)
# Out:
# [ 1 10  8  1  5]

# %% [markdown]
# One function of numpy that you will use a lot are simple statistics like the mean or median. If you don't remember what these all are, read up and play at https://www.w3schools.com/python/python_ml_mean_median_mode.asp.
#
# You can calculate the mean of friends' visits with ```np.mean(friends_array)```.

# %%
np.mean(friends_array)
# Out:
# np.float64(3.0)

# %% [markdown]
# For the median, try ```np.median(friends_array)```.

# %%
np.median(friends_array)
# Out:
# np.float64(3.0)

# %% [markdown]
# The mean value is the average value. The median value is the value in the middle, after you have sorted all the values. If they are close together, the values are fairly evenly distributed. We talk about this more next week.
#
# Matrices are important in data analysis. They are two-dimensional arrays. For instance, black and white images are such matrices. They contain a pixel value at the horizontal and vertical dimension.
#
# We can create a matrix called meetings by simply combing `friends_array` and `colleagues_array`. Type in ```meetings = np.array([friends_array, colleagues_array])```. Print out `meetings`.

# %%
meetings = np.array([friends_array, colleagues_array])
print(meetings)
# Out:
# [[ 5  4  2  1  3]
#  [ 1 10  8  1  5]]

# %% [markdown]
# Type in `meetings.shape` and analyse the output.

# %%
meetings.shape
# Out:
# (2, 5)

# %% [markdown]
# The attribute `shape` gives you the dimensions of an array.
#
# We can then ask a couple of good questions against the matrix views without having to reference the arrays it is made of.
#
# To find out on which days we had 5 meetings with either friends or colleagues, we type ```meetings == 5```. The == is the Boolean equivalence operator.

# %%
meetings == 5
# Out:
# array([[ True, False, False, False, False],
#        [False, False, False, False,  True]])

# %% [markdown]
# Want to see something nice? It is very easy to find out the number of times meetings == 5 with `np.sum(meetings == 5)`.

# %%
np.sum(meetings == 5)
# Out:
# np.int64(2)

# %% [markdown]
# This is very advanced and something you will learn over time, but all Boolean values are at the same time 0 or 1 for False or True. With `np.sum`, we simply sum up the number of times we have True (which equals 1) in meetings.
#
# When are the meetings less than or equal to 7? Try ```meetings <= 7```.

# %%
meetings <= 7
# Out:
# array([[ True,  True,  True,  True,  True],
#        [ True, False, False,  True,  True]])

# %% [markdown]
# How often do I meet friends equal or more than colleagues times two? This is actually a quite advanced expression already. Try it with ```np.sum(friends_array >= (colleagues_array * 2))```.

# %%
np.sum(friends_array >= colleagues_array * 2)
# Out:
# np.int64(1)

# %% [markdown]
# Take a moment to think about the components of this expression. Maybe, you want to take a piece of paper and pen to write down all the components. Hint: As said, Boolean variables can also be thought of a 0 for False and 1 for True.
#
# Similar to arrays, we can access each element of a matrix, but this time we have 2 dimensions. ``meetings[0][2]`` will select the first row's second element. Try it.

# %%
meetings[0][2]
# Out:
# np.int64(2)

# %% [markdown]
# The order of indexes is row first and then column. Enter `meetings[1][2]`.

# %%
meetings[1][2]
# Out:
# np.int64(8)

# %% [markdown]
# Be very careful with indexes. If you go beyond the numnber of elements in lists or arrays you produce an error. Try ```meetings[2][2]```.

# %% [markdown]
# It is called 'index out of bounds' and is very common error in programming.
#
# This is very important for image-processing, as we will see later on. Images in Python are treated as matrices because they consist of pixels arranged in a grid—rows and columns. Think of your screen in front of you.
#
# It's time to practice and read up a bit at https://numpy.org/doc/stable/user/absolute_beginners.html.
#
# We are almost done for today. Finally, we want to look at what are called control structure for events and loops. They are both very powerful.

# %% [markdown]
# ## Event-driven and Sequential
#
# In this week's workshop, we will go again over all the concepts and practices we have just discussed.  But before that, we need to introduce a few more aspects of Python, the programming language, which you might need in data analysis tasks, but they are much more common if you want to program say an app. The first topic are control structures.
#
# Control structures execute a piece of code based on a condition. You can recognize them in most programming languages by the keyword `if`. In Python, they look like the cell below. Run the next cell, please.

# %%
#Keep cell
medium = 'Social Media'

if (medium == 'Social Media'):
    print('Showing Social Media information')
# Out:
# Showing Social Media information

# %% [markdown]
# The first statement creates a variable `medium` with 'Social Media' as a value. The control structure starts with `if`, then uses a condition to evaluate to a Boolean (`medium == 'Social Media'`), followed by a colon. The statement to execute follows in the next line.  `print('Showing Social Media information')` will print out if the condition is met.
#
# Important: Observe the indentation, which is a way of telling Python that a group of statements belongs together as a block. Blocks can be regarded as the grouping of statements for a specific purpose. Python really does not like if you mess with its indentation. Check https://www.dummies.com/programming/python/how-to-indent-and-dedent-your-python-code/.
#
# Now, also assign ```num_views = 1001```.

# %%
medium = 'Social Media'

if (medium == 'Social Media'):
    print('Showing Social Media information')

num_views = 1001
# Out:
# Showing Social Media information

# %% [markdown]
# Let's try to confirm whether we are popular with ```if num_views > 1000``` then print 'You are very popular!'
#
# Now, using the `num_views` variable, write an if statement that prints 'You are very popular!' if `num_views` is greater than 1000. You can do it ...

# %%
if num_views >= 1000:
  print('You are very popular!')
# Out:
# You are very popular!

# %% [markdown]
# You can combine Boolean expressions/conditions also logically.
#
#
# The keyword 'and' stands for a logical and, while 'or' stands for the logical or in Python.
#
# Try the logical combination and and type in:
#
# ```
# if (num_views > 1000) and (medium == 'Social Media'):
#     print('You are popular on Social Media!')
# ```
#
# Explain the results!

# %%
if (num_views > 1000) and (medium == 'Social Media'):
  print('You are popular on Social Media!')
# Out:
# You are popular on Social Media!

# %% [markdown]
# `num_views > 1000` and `medium == 'Social Media'` means that the if condition is met and 'You are popular on Social Media!' is printed.
#
# Finally, you can also tell the computer to do other work if the condition is not fulfilled. You need to use the keyword `else`. Run the cell below and observe the indentation ...

# %%
#Keep cell

if (num_views > 1000) and (medium == 'Social Media'):
    print('Condition met.')
    print('You are popular on Social Media!')
else:
    print('Condition not met.')
    print('Try to be more visible!')
# Out:
# Condition met.
# You are popular on Social Media!

# %% [markdown]
# W3Schools is a great free site with lots of exercises on various aspects of the Python programming language. Go to https://www.w3schools.com/python/python_conditions.asp and complete all the exercises before you continue. As you can see there are other topics, too, like variables: https://www.w3schools.com/python/python_variables.asp. We will come back to the site from time to time to keep practicing.
#
# These are control statements. Let's move on to sequences and loops.
#
# Loops can be used to iterate over the elements of lists and arrays. Let's look at our friends again. Print out ```friends_list``` and ```friends_array```. You need to use the print statement and ```,``` to print them out both at the same time. Do you remember how?

# %%
print(friends_list, friends_array)
# Out:
# [2, 3, 2, 4, 5] [5 4 2 1 3]

# %% [markdown]
# Can you achieve the same result with an f-string? Try it ...
#
# In our Python world of data analysis, for-loops are especially important. They are used to iterate over a sequence (like a sequence of letters in a string here). The cell below shows the syntax. Run it.

# %%
#Keep cell

for letter in 'LinkedIn':
    print(letter)
# Out:
# L
# i
# n
# k
# e
# d
# I
# n

# %% [markdown]
# For-loops can be very useful to perform repeated operations on collections of data, which is something we often want to do in data analysis. So, for instance, loops could be used to get the square of each element in a list/array, etc.
#
# The next cell introduces the ```for x in``` construct, which is a short form for going through elements in a for loop. Run the following code to square each number in our ```range(9)``` and observe the code:
#
# ```
# for i in range(9):
#     print(i**2)
#
# ```
#
# ```i**2``` is the power-operator in Python.

# %%
for i in range(9):
  print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64

# %% [markdown]
# This was a lot of stuff for the first lesson. Unfortunately, this is necessary but once you have learned one programming language all of this becomes quite obvious and repetitive.
#
# Now, we are ready to use loops for what we generally use them for and access each element in a list of array. Please create a for-loop to iterate over `friends_list`. It is very easy in Python but watch out for those indentations.
#
# ```
# for f in friends_list:
#   print(f)
# ```

# %%
for f in friends_list:
  print(f)
# Out:
# 2
# 3
# 2
# 4
# 5

# %% [markdown]
# The for-loop starts with a `for`, then the variable to iterate with, then the `in`, plus finally the list followed by a colon.
#
# You can do the same with the array. Try:
#
# ```
# for f in friends_array:
#   print(f)
# ```

# %%
for f in friends_array:
  print(f)
# Out:
# 5
# 4
# 2
# 1
# 3

# %% [markdown]
# You can also use an index that runs from 0 to 5 in these two cases. Remember the function ```range``` from earlier? It was easy to miss. Try ```list(range(5))``` and observe how it creates a list from 0 to 4.

# %%
for a in range(5):
  print(a)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# So, to use an index i to iterate over friends_list, enter
# ```
# for i in list(range(5)):
#   print(friends_list[i])
# ```

# %%
for i in list(range(5)):
  print(friends_list[i])
# Out:
# 2
# 3
# 2
# 4
# 5

# %% [markdown]
# Now, we can update each element in the list. To double the values, run:
#
# ```
# for i in list(range(5)):
#   friends_list[i] = friends_list[i] * 2
# ```

# %%
for i in list(range(5)):
  friends_list[i] = friends_list[i] * 2

# %% [markdown]
# Print out `friends_list` and compare.

# %%
print(friends_list)
# Out:
# [4, 6, 4, 8, 10]

# %% [markdown]
# This is where arrays are much easier. Here you do not have to use a for-loop. Run ```friends_array = friends_array * 2``` and be amazed.

# %%
friends_array = friends_array * 2

# %% [markdown]
# This updates the elements of friends_array directly. Print `friends_array`.

# %%
print(friends_array)
# Out:
# [10  8  4  2  6]

# %% [markdown]
# Let's bring loops and conditions together and compare `friends_list` and `friends_array`.
#
# We want to print out the 'The lists have it!' each time the `friends_list` element at position `i` is larger or equal the `friends_array` element at position `i`. Otherwise, we print 'The arrays have it!'.
#
# Take a moment to think how to do it. You need both for-loops and if-statements.

# %% [markdown]
# After some thinking, you type:
#
# ```
# for i in list(range(5)):
#     if (friends_list[i]>=friends_array[i]):
#         print('The lists have it!')
#     else:
#         print('The arrays have it!')
# ```

# %%
for i in list(range(5)):
    if (friends_list[i]>=friends_array[i]):
        print('The lists have it!')
    else:
        print('The arrays have it!')
# Out:
# The arrays have it!
# The arrays have it!
# The lists have it!
# The lists have it!
# The lists have it!

# %% [markdown]
# Have even more fun with for-loops at https://www.w3schools.com/python/python_for_loops.asp.
#
# Looking forward to seeing you again at the workshops.
